# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_general = pd.read_csv("WHO-COVID-19-global-data.csv")
df_daily = pd.read_csv("WHO-COVID-19-global-data.csv", index_col= None)
vaccination = pd.read_csv("vaccination-data.csv")

# %%
df_general
# Out:
#        Date_reported Country_code      Country WHO_region  New_cases  \
# 0         2020-01-03           AF  Afghanistan       EMRO          0
# 1         2020-01-04           AF  Afghanistan       EMRO          0
# 2         2020-01-05           AF  Afghanistan       EMRO          0
# 3         2020-01-06           AF  Afghanistan       EMRO          0
# 4         2020-01-07           AF  Afghanistan       EMRO          0
# ...              ...          ...          ...        ...        ...
# 165184    2021-11-25           ZW     Zimbabwe       AFRO         40
# 165185    2021-11-26           ZW     Zimbabwe       AFRO         27
# 165186    2021-11-27           ZW     Zimbabwe       AFRO         62
# 165187    2021-11-28           ZW     Zimbabwe       AFRO        115
# 165188    2021-11-29           ZW     Zimbabwe       AFRO         40
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 0                      0           0                  0
# ...

# %%
df_daily
# Out:
#        Date_reported Country_code      Country WHO_region  New_cases  \
# 0         2020-01-03           AF  Afghanistan       EMRO          0
# 1         2020-01-04           AF  Afghanistan       EMRO          0
# 2         2020-01-05           AF  Afghanistan       EMRO          0
# 3         2020-01-06           AF  Afghanistan       EMRO          0
# 4         2020-01-07           AF  Afghanistan       EMRO          0
# ...              ...          ...          ...        ...        ...
# 165184    2021-11-25           ZW     Zimbabwe       AFRO         40
# 165185    2021-11-26           ZW     Zimbabwe       AFRO         27
# 165186    2021-11-27           ZW     Zimbabwe       AFRO         62
# 165187    2021-11-28           ZW     Zimbabwe       AFRO        115
# 165188    2021-11-29           ZW     Zimbabwe       AFRO         40
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 0                      0           0                  0
# ...

# %%
brazil_vac = vaccination[vaccination["COUNTRY"]=="Brazil"]

# %%
brazil_vac
# Out:
#    COUNTRY ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  TOTAL_VACCINATIONS  \
# 29  Brazil  BRA       AMRO   REPORTING   2021-11-29           306982366
#
#     PERSONS_VACCINATED_1PLUS_DOSE  TOTAL_VACCINATIONS_PER100  \
# 29                    158513468.0                    144.422
#
#     PERSONS_VACCINATED_1PLUS_DOSE_PER100  PERSONS_FULLY_VACCINATED  \
# 29                                74.574               134618389.0
#
#     PERSONS_FULLY_VACCINATED_PER100  \
# 29                           63.332
#
#                                         VACCINES_USED FIRST_VACCINE_DATE  \
# 29  AstraZeneca - Vaxzevria,Janssen - Ad26.COV 2-S...         2021-01-17
#
#     NUMBER_VACCINES_TYPES_USED
# 29                         5.0

# %%
brazil_cases = df_general[df_general["Country"]=="Brazil"]

# %%
brazil_cases
# Out:
#       Date_reported Country_code Country WHO_region  New_cases  \
# 19516    2020-01-03           BR  Brazil       AMRO          0
# 19517    2020-01-04           BR  Brazil       AMRO          0
# 19518    2020-01-05           BR  Brazil       AMRO          0
# 19519    2020-01-06           BR  Brazil       AMRO          0
# 19520    2020-01-07           BR  Brazil       AMRO          0
# ...             ...          ...     ...        ...        ...
# 20208    2021-11-25           BR  Brazil       AMRO      10312
# 20209    2021-11-26           BR  Brazil       AMRO      12930
# 20210    2021-11-27           BR  Brazil       AMRO      12126
# 20211    2021-11-28           BR  Brazil       AMRO      12392
# 20212    2021-11-29           BR  Brazil       AMRO       9233
#
#        Cumulative_cases  New_deaths  Cumulative_deaths
# 19516                 0           0                  0
# 19517                 0           0                  0
# ...

# %%
uk_vac = vaccination[vaccination["COUNTRY"]=="The United Kingdom"]

# %%
uk_vac
# Out:
#                 COUNTRY ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  \
# 203  The United Kingdom  GBR       EURO   REPORTING   2021-11-23
#
#      TOTAL_VACCINATIONS  PERSONS_VACCINATED_1PLUS_DOSE  \
# 203           112277085                     50777474.0
#
#      TOTAL_VACCINATIONS_PER100  PERSONS_VACCINATED_1PLUS_DOSE_PER100  \
# 203                      165.4                                74.607
#
#      PERSONS_FULLY_VACCINATED  PERSONS_FULLY_VACCINATED_PER100  \
# 203                46050470.0                           67.835
#
#                                          VACCINES_USED FIRST_VACCINE_DATE  \
# 203  AstraZeneca - Vaxzevria,Moderna - Spikevax,Pfi...         2020-12-21
#
#      NUMBER_VACCINES_TYPES_USED
# 203                         3.0

# %%
uk_cases = df_general[df_general["Country"]=="The United Kingdom"]

# %%
uk_cases
# Out:
#        Date_reported Country_code             Country WHO_region  New_cases  \
# 147067    2020-01-03           GB  The United Kingdom       EURO          0
# 147068    2020-01-04           GB  The United Kingdom       EURO          0
# 147069    2020-01-05           GB  The United Kingdom       EURO          0
# 147070    2020-01-06           GB  The United Kingdom       EURO          0
# 147071    2020-01-07           GB  The United Kingdom       EURO          0
# ...              ...          ...                 ...        ...        ...
# 147759    2021-11-25           GB  The United Kingdom       EURO      42435
# 147760    2021-11-26           GB  The United Kingdom       EURO      46654
# 147761    2021-11-27           GB  The United Kingdom       EURO      49344
# 147762    2021-11-28           GB  The United Kingdom       EURO      39567
# 147763    2021-11-29           GB  The United Kingdom       EURO      36507
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# ...

# %%
usa_vac = vaccination[vaccination["COUNTRY"]=="United States of America"]

# %%
usa_vac
# Out:
#                       COUNTRY ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  \
# 218  United States of America  USA       AMRO   REPORTING   2021-11-29
#
#      TOTAL_VACCINATIONS  PERSONS_VACCINATED_1PLUS_DOSE  \
# 218           493149970                    275120582.0
#
#      TOTAL_VACCINATIONS_PER100  PERSONS_VACCINATED_1PLUS_DOSE_PER100  \
# 218                    148.987                                83.117
#
#      PERSONS_FULLY_VACCINATED  PERSONS_FULLY_VACCINATED_PER100  \
# 218               197189801.0                           59.573
#
#                                          VACCINES_USED FIRST_VACCINE_DATE  \
# 218  Janssen - Ad26.COV 2-S,Moderna - Spikevax,Pfiz...         2020-12-14
#
#      NUMBER_VACCINES_TYPES_USED
# 218                         3.0

# %%
usa_cases = df_general[df_general["Country"]=="United States of America"]

# %%
usa_cases
# Out:
#        Date_reported Country_code                   Country WHO_region  \
# 157522    2020-01-03           US  United States of America       AMRO
# 157523    2020-01-04           US  United States of America       AMRO
# 157524    2020-01-05           US  United States of America       AMRO
# 157525    2020-01-06           US  United States of America       AMRO
# 157526    2020-01-07           US  United States of America       AMRO
# ...              ...          ...                       ...        ...
# 158214    2021-11-25           US  United States of America       AMRO
# 158215    2021-11-26           US  United States of America       AMRO
# 158216    2021-11-27           US  United States of America       AMRO
# 158217    2021-11-28           US  United States of America       AMRO
# 158218    2021-11-29           US  United States of America       AMRO
#
#         New_cases  Cumulative_cases  New_deaths  Cumulative_deaths
# ...

# %%
brazil_cases
# Out:
#       Date_reported Country_code Country WHO_region  New_cases  \
# 19516    2020-01-03           BR  Brazil       AMRO          0
# 19517    2020-01-04           BR  Brazil       AMRO          0
# 19518    2020-01-05           BR  Brazil       AMRO          0
# 19519    2020-01-06           BR  Brazil       AMRO          0
# 19520    2020-01-07           BR  Brazil       AMRO          0
# ...             ...          ...     ...        ...        ...
# 20208    2021-11-25           BR  Brazil       AMRO      10312
# 20209    2021-11-26           BR  Brazil       AMRO      12930
# 20210    2021-11-27           BR  Brazil       AMRO      12126
# 20211    2021-11-28           BR  Brazil       AMRO      12392
# 20212    2021-11-29           BR  Brazil       AMRO       9233
#
#        Cumulative_cases  New_deaths  Cumulative_deaths
# 19516                 0           0                  0
# 19517                 0           0                  0
# ...

# %%
new_zealand_vac = vaccination[vaccination["COUNTRY"]=="New Zealand"]

# %%
new_zealand_vac
# Out:
#          COUNTRY ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  TOTAL_VACCINATIONS  \
# 145  New Zealand  NZL       WPRO   REPORTING   2021-11-12             7170281
#
#      PERSONS_VACCINATED_1PLUS_DOSE  TOTAL_VACCINATIONS_PER100  \
# 145                      3786316.0                    148.692
#
#      PERSONS_VACCINATED_1PLUS_DOSE_PER100  PERSONS_FULLY_VACCINATED  \
# 145                                78.518                 3383965.0
#
#      PERSONS_FULLY_VACCINATED_PER100  \
# 145                           70.174
#
#                                          VACCINES_USED FIRST_VACCINE_DATE  \
# 145  AstraZeneca - Vaxzevria,Janssen - Ad26.COV 2-S...         2021-02-19
#
#      NUMBER_VACCINES_TYPES_USED
# 145                         4.0

# %%
new_zealand_cases = df_general[df_general["Country"]=="New Zealand"]

# %%
new_zealand_cases
# Out:
#        Date_reported Country_code      Country WHO_region  New_cases  \
# 103156    2020-01-03           NZ  New Zealand       WPRO          0
# 103157    2020-01-04           NZ  New Zealand       WPRO          0
# 103158    2020-01-05           NZ  New Zealand       WPRO          0
# 103159    2020-01-06           NZ  New Zealand       WPRO          0
# 103160    2020-01-07           NZ  New Zealand       WPRO          0
# ...              ...          ...          ...        ...        ...
# 103848    2021-11-25           NZ  New Zealand       WPRO        182
# 103849    2021-11-26           NZ  New Zealand       WPRO        177
# 103850    2021-11-27           NZ  New Zealand       WPRO        145
# 103851    2021-11-28           NZ  New Zealand       WPRO        146
# 103852    2021-11-29           NZ  New Zealand       WPRO        185
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 103156                 0           0                  0
# ...

# %%
turkey_vac = vaccination[vaccination["COUNTRY"]=="Turkey"]

# %%
turkey_vac
# Out:
#     COUNTRY ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  TOTAL_VACCINATIONS  \
# 210  Turkey  TUR       EURO        OWID   2021-11-24           119327719
#
#      PERSONS_VACCINATED_1PLUS_DOSE  TOTAL_VACCINATIONS_PER100  \
# 210                     56038139.0                      141.5
#
#      PERSONS_VACCINATED_1PLUS_DOSE_PER100  PERSONS_FULLY_VACCINATED  \
# 210                                 67.39                50750190.0
#
#      PERSONS_FULLY_VACCINATED_PER100  \
# 210                           60.174
#
#                                         VACCINES_USED FIRST_VACCINE_DATE  \
# 210  Pfizer BioNTech - Comirnaty, Sinovac - CoronaVac                NaN
#
#      NUMBER_VACCINES_TYPES_USED
# 210                         2.0

# %%
turkey_cases = df_general[df_general["Country"]=="Turkey"]

# %%
turkey_cases
# Out:
#        Date_reported Country_code Country WHO_region  New_cases  \
# 151946    2020-01-03           TR  Turkey       EURO          0
# 151947    2020-01-04           TR  Turkey       EURO          0
# 151948    2020-01-05           TR  Turkey       EURO          0
# 151949    2020-01-06           TR  Turkey       EURO          0
# 151950    2020-01-07           TR  Turkey       EURO          0
# ...              ...          ...     ...        ...        ...
# 152638    2021-11-25           TR  Turkey       EURO      27592
# 152639    2021-11-26           TR  Turkey       EURO      24467
# 152640    2021-11-27           TR  Turkey       EURO      24002
# 152641    2021-11-28           TR  Turkey       EURO      23759
# 152642    2021-11-29           TR  Turkey       EURO      21655
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 151946                 0           0                  0
# 151947                 0           0                  0
# ...

# %%
china_vac = vaccination[vaccination["COUNTRY"]=="China"]

# %%
china_vac
# Out:
#    COUNTRY ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  TOTAL_VACCINATIONS  \
# 43   China  CHN       WPRO   REPORTING   2021-11-19          2433028166
#
#     PERSONS_VACCINATED_1PLUS_DOSE  TOTAL_VACCINATIONS_PER100  \
# 43                   1.155161e+09                    165.367
#
#     PERSONS_VACCINATED_1PLUS_DOSE_PER100  PERSONS_FULLY_VACCINATED  \
# 43                                78.514              1.014892e+09
#
#     PERSONS_FULLY_VACCINATED_PER100  \
# 43                            68.98
#
#                                         VACCINES_USED FIRST_VACCINE_DATE  \
# 43  Anhui ZL - Recombinant,Beijing CNBG - BBIBP-Co...         2020-07-22
#
#     NUMBER_VACCINES_TYPES_USED
# 43                         8.0

# %%
china_cases = df_general[df_general["Country"]=="China"]

# %%
china_cases
# Out:
#       Date_reported Country_code Country WHO_region  New_cases  \
# 29274    2020-01-03           CN   China       WPRO          0
# 29275    2020-01-04           CN   China       WPRO          1
# 29276    2020-01-05           CN   China       WPRO          0
# 29277    2020-01-06           CN   China       WPRO          3
# 29278    2020-01-07           CN   China       WPRO          0
# ...             ...          ...     ...        ...        ...
# 29966    2021-11-25           CN   China       WPRO         30
# 29967    2021-11-26           CN   China       WPRO         29
# 29968    2021-11-27           CN   China       WPRO         41
# 29969    2021-11-28           CN   China       WPRO         38
# 29970    2021-11-29           CN   China       WPRO         54
#
#        Cumulative_cases  New_deaths  Cumulative_deaths
# 29274                 0           0                  0
# 29275                 1           0                  0
# ...

# %%
india_vac = vaccination[vaccination["COUNTRY"]=="India"]

# %%
india_vac
# Out:
#    COUNTRY ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  TOTAL_VACCINATIONS  \
# 94   India  IND      SEARO   REPORTING   2021-11-23          1183573646
#
#     PERSONS_VACCINATED_1PLUS_DOSE  TOTAL_VACCINATIONS_PER100  \
# 94                    770622080.0                     85.766
#
#     PERSONS_VACCINATED_1PLUS_DOSE_PER100  PERSONS_FULLY_VACCINATED  \
# 94                                55.842               412951566.0
#
#     PERSONS_FULLY_VACCINATED_PER100  \
# 94                           29.924
#
#                                         VACCINES_USED FIRST_VACCINE_DATE  \
# 94  Bharat - Covaxin,Gamaleya - Gam-Covid-Vac,Jans...         2021-01-16
#
#     NUMBER_VACCINES_TYPES_USED
# 94                         5.0

# %%
india_cases = df_general[df_general["Country"]=="India"]

# %%
india_cases
# Out:
#       Date_reported Country_code Country WHO_region  New_cases  \
# 66912    2020-01-03           IN   India      SEARO          0
# 66913    2020-01-04           IN   India      SEARO          0
# 66914    2020-01-05           IN   India      SEARO          0
# 66915    2020-01-06           IN   India      SEARO          0
# 66916    2020-01-07           IN   India      SEARO          0
# ...             ...          ...     ...        ...        ...
# 67604    2021-11-25           IN   India      SEARO       9119
# 67605    2021-11-26           IN   India      SEARO      10549
# 67606    2021-11-27           IN   India      SEARO       8318
# 67607    2021-11-28           IN   India      SEARO       8774
# 67608    2021-11-29           IN   India      SEARO       8309
#
#        Cumulative_cases  New_deaths  Cumulative_deaths
# 66912                 0           0                  0
# 66913                 0           0                  0
# ...

# %%
turkey_cases
# Out:
#        Date_reported Country_code Country WHO_region  New_cases  \
# 151946    2020-01-03           TR  Turkey       EURO          0
# 151947    2020-01-04           TR  Turkey       EURO          0
# 151948    2020-01-05           TR  Turkey       EURO          0
# 151949    2020-01-06           TR  Turkey       EURO          0
# 151950    2020-01-07           TR  Turkey       EURO          0
# ...              ...          ...     ...        ...        ...
# 152638    2021-11-25           TR  Turkey       EURO      27592
# 152639    2021-11-26           TR  Turkey       EURO      24467
# 152640    2021-11-27           TR  Turkey       EURO      24002
# 152641    2021-11-28           TR  Turkey       EURO      23759
# 152642    2021-11-29           TR  Turkey       EURO      21655
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 151946                 0           0                  0
# 151947                 0           0                  0
# ...

# %%
turkey_cases["Date_reported"] = pd.to_datetime(turkey_cases["Date_reported"])
# Out:
# <ipython-input-47-5b963dea2bf9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   turkey_cases["Date_reported"] = pd.to_datetime(turkey_cases["Date_reported"])

# %%
turkey_cases
# Out:
#        Date_reported Country_code Country WHO_region  New_cases  \
# 151946    2020-01-03           TR  Turkey       EURO          0
# 151947    2020-01-04           TR  Turkey       EURO          0
# 151948    2020-01-05           TR  Turkey       EURO          0
# 151949    2020-01-06           TR  Turkey       EURO          0
# 151950    2020-01-07           TR  Turkey       EURO          0
# ...              ...          ...     ...        ...        ...
# 152638    2021-11-25           TR  Turkey       EURO      27592
# 152639    2021-11-26           TR  Turkey       EURO      24467
# 152640    2021-11-27           TR  Turkey       EURO      24002
# 152641    2021-11-28           TR  Turkey       EURO      23759
# 152642    2021-11-29           TR  Turkey       EURO      21655
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 151946                 0           0                  0
# 151947                 0           0                  0
# ...

# %%
plt.figure(figsize=(20,10))
ax = sns.lineplot(data=turkey_cases,
            x="Date_reported",
            y="New_cases",
            )
plt.xticks(rotation=45)
ax.set_title("Turkey Corona Cases From Start")
plt.show()

# %%
turkey_cases[turkey_cases["Date_reported"]=="2020-10-30"]
# Out:
#        Date_reported Country_code Country WHO_region  New_cases  \
# 152247    2020-10-30           TR  Turkey       EURO       9049
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 152247           1003452          72              10099

# %%
df_general["Date_reported"] = pd.to_datetime(df_general["Date_reported"])

# %%
uk_cases["Date_reported"] = pd.to_datetime(uk_cases["Date_reported"])
# Out:
# <ipython-input-52-8429936f45f9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uk_cases["Date_reported"] = pd.to_datetime(uk_cases["Date_reported"])

# %%
plt.figure(figsize=(20,10))
ax = sns.lineplot(data=uk_cases,
            x="Date_reported",
            y="New_cases",
            )
plt.xticks(rotation=45)
ax.set_title("UK Corona Cases From Start")
plt.show()

# %%
chosen_cases = pd.concat([uk_cases, turkey_cases, india_cases, usa_cases, new_zealand_cases,brazil_cases], axis=0)

# %%
chosen_cases
# Out:
#               Date_reported Country_code             Country WHO_region  \
# 147067  2020-01-03 00:00:00           GB  The United Kingdom       EURO
# 147068  2020-01-04 00:00:00           GB  The United Kingdom       EURO
# 147069  2020-01-05 00:00:00           GB  The United Kingdom       EURO
# 147070  2020-01-06 00:00:00           GB  The United Kingdom       EURO
# 147071  2020-01-07 00:00:00           GB  The United Kingdom       EURO
# ...                     ...          ...                 ...        ...
# 20208            2021-11-25           BR              Brazil       AMRO
# 20209            2021-11-26           BR              Brazil       AMRO
# 20210            2021-11-27           BR              Brazil       AMRO
# 20211            2021-11-28           BR              Brazil       AMRO
# 20212            2021-11-29           BR              Brazil       AMRO
#
#         New_cases  Cumulative_cases  New_deaths  Cumulative_deaths
# ...

# %%
plt.figure(figsize=(30,10))
ax = sns.lineplot(data=chosen_cases,
            x="Date_reported",
            y="New_cases",
            hue="Country",
            size="Country"
            )
plt.xticks(rotation=45)
ax.set_xlabel("Date_reported",fontsize=30)
ax.set_ylabel("New_cases",fontsize=30)
ax.set_title("Sample Countries Corona Cases From Start", fontsize=30)
plt.show()

# %%
china_cases["Date_reported"] = pd.to_datetime(china_cases["Date_reported"])
# Out:
# <ipython-input-57-3ff61aaa27d6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   china_cases["Date_reported"] = pd.to_datetime(china_cases["Date_reported"])

# %%
plt.figure(figsize=(30,10))
ax = sns.lineplot(data=china_cases,
            x="Date_reported",
            y="New_cases",
            hue="Country",
            size="Country"
            )
plt.xticks(rotation=45)
ax.set_xlabel("Date_reported",fontsize=30)
ax.set_ylabel("New_cases",fontsize=30)
ax.set_title("Sample Countries Corona Cases From Start", fontsize=30)
plt.show()

# %%
df_general
# Out:
#        Date_reported Country_code      Country WHO_region  New_cases  \
# 0         2020-01-03           AF  Afghanistan       EMRO          0
# 1         2020-01-04           AF  Afghanistan       EMRO          0
# 2         2020-01-05           AF  Afghanistan       EMRO          0
# 3         2020-01-06           AF  Afghanistan       EMRO          0
# 4         2020-01-07           AF  Afghanistan       EMRO          0
# ...              ...          ...          ...        ...        ...
# 165184    2021-11-25           ZW     Zimbabwe       AFRO         40
# 165185    2021-11-26           ZW     Zimbabwe       AFRO         27
# 165186    2021-11-27           ZW     Zimbabwe       AFRO         62
# 165187    2021-11-28           ZW     Zimbabwe       AFRO        115
# 165188    2021-11-29           ZW     Zimbabwe       AFRO         40
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 0                      0           0                  0
# ...

# %%
plt.figure(figsize=(30,10))
ax = sns.lineplot(data=chosen_cases,
            x="Date_reported",
            y="Cumulative_deaths",
            hue="Country",
            size="Country"
            )
plt.xticks(rotation=45)
ax.set_xlabel("Date_reported",fontsize=30)
ax.set_ylabel("New_cases",fontsize=30)
ax.set_title("Sample Countries Corona Cases From Start", fontsize=30)
plt.show()

# %%
df_general["Hospital Service Power"] = df_general["Cumulative_deaths"]/df_general["Cumulative_cases"]

# %%
df_general
# Out:
#        Date_reported Country_code      Country WHO_region  New_cases  \
# 0         2020-01-03           AF  Afghanistan       EMRO          0
# 1         2020-01-04           AF  Afghanistan       EMRO          0
# 2         2020-01-05           AF  Afghanistan       EMRO          0
# 3         2020-01-06           AF  Afghanistan       EMRO          0
# 4         2020-01-07           AF  Afghanistan       EMRO          0
# ...              ...          ...          ...        ...        ...
# 165184    2021-11-25           ZW     Zimbabwe       AFRO         40
# 165185    2021-11-26           ZW     Zimbabwe       AFRO         27
# 165186    2021-11-27           ZW     Zimbabwe       AFRO         62
# 165187    2021-11-28           ZW     Zimbabwe       AFRO        115
# 165188    2021-11-29           ZW     Zimbabwe       AFRO         40
#
#         Cumulative_cases  New_deaths  Cumulative_deaths  \
# 0                      0           0                  0
# ...

# %%
uk_cases["Hospital Service Weakness"] = uk_cases["Cumulative_deaths"]/uk_cases["Cumulative_cases"]
# Out:
# <ipython-input-63-22eb6698c3e6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uk_cases["Hospital Service Weakness"] = uk_cases["Cumulative_deaths"]/uk_cases["Cumulative_cases"]

# %%
uk_cases
# Out:
#        Date_reported Country_code             Country WHO_region  New_cases  \
# 147067    2020-01-03           GB  The United Kingdom       EURO          0
# 147068    2020-01-04           GB  The United Kingdom       EURO          0
# 147069    2020-01-05           GB  The United Kingdom       EURO          0
# 147070    2020-01-06           GB  The United Kingdom       EURO          0
# 147071    2020-01-07           GB  The United Kingdom       EURO          0
# ...              ...          ...                 ...        ...        ...
# 147759    2021-11-25           GB  The United Kingdom       EURO      42435
# 147760    2021-11-26           GB  The United Kingdom       EURO      46654
# 147761    2021-11-27           GB  The United Kingdom       EURO      49344
# 147762    2021-11-28           GB  The United Kingdom       EURO      39567
# 147763    2021-11-29           GB  The United Kingdom       EURO      36507
#
# ...

# %%
plt.figure(figsize=(30,10))
ax = sns.lineplot(data=uk_cases,
            x="Date_reported",
            y="Hospital Service Weakness"
            )
plt.xticks(rotation=45)
ax.set_xlabel("Date_reported",fontsize=30)
ax.set_ylabel("New_cases",fontsize=30)
ax.set_title("Sample Countries Corona Cases From Start", fontsize=30)
plt.show()

# %%
chosen_cases["Hospital Service Weakness"] = chosen_cases["Cumulative_deaths"]/chosen_cases["Cumulative_cases"]

# %%
del df_general["Hospital Service Power"]

# %%
697*30
# Out:
# 20910

# %%
df_general["Hospital Service Weakness"] = df_general["Cumulative_deaths"]/df_general["Cumulative_cases"]

# %%
df_general[df_general["Date_reported"]=="2021-11-28"].sort_values("Hospital Service Weakness", ascending=False).head(30)
# Out:
#        Date_reported Country_code                           Country  \
# 163793    2021-11-28           YE                             Yemen
# 115003    2021-11-28           PE                              Peru
# 94093     2021-11-28           MX                            Mexico
# 142883    2021-11-28           SD                             Sudan
# 42515     2021-11-28           EC                           Ecuador
# 139398    2021-11-28           SO                           Somalia
# 145671    2021-11-28           SY              Syrian Arab Republic
# 43212     2021-11-28           EG                             Egypt
# 82941     2021-11-28           LR                           Liberia
# 695       2021-11-28           AF                       Afghanistan
# 18817     2021-11-28           BA            Bosnia and Herzegovina
# 29969     2021-11-28           CN                             China
# 22302     2021-11-28           BG                          Bulgaria
# ...

# %%
df_general[df_general["Date_reported"]=="2021-11-28"].sort_values("Hospital Service Weakness", ascending=True).head(30)
# Out:
#        Date_reported Country_code  \
# 48091     2021-11-28           FK
# 124064    2021-11-28           XC
# 90608     2021-11-28           MH
# 2786      2021-11-28           AS
# 57849     2021-11-28           GL
# 128246    2021-11-28           PM
# 129640    2021-11-28           WS
# 161005    2021-11-28           VU
# 150550    2021-11-28           TO
# 112215    2021-11-28           PW
# 64819     2021-11-28           VA
# 135913    2021-11-28           XB
# 138701    2021-11-28           SB
# 27181     2021-11-28           KY
# 23696     2021-11-28           BI
# 16726     2021-11-28           BT
# 66910     2021-11-28           IS
# 80153     2021-11-28           LA
# 4877      2021-11-28           AI
# 124761    2021-11-28           BL
# 119185    2021-11-28           QA
# 135216    2021-11-28           SG
# 88517     2021-11-28           MV
# 156823    2021-11-28           AE
# 48788     2021-11-28           FO
# 21605     2021-11-28           BN
# ...

# %%
df_general[df_general["Date_reported"]=="2021-11-28"].sort_values("Hospital Service Weakness", ascending=True).iloc[13:34]
# Out:
#        Date_reported Country_code  \
# 27181     2021-11-28           KY
# 23696     2021-11-28           BI
# 16726     2021-11-28           BT
# 66910     2021-11-28           IS
# 80153     2021-11-28           LA
# 4877      2021-11-28           AI
# 124761    2021-11-28           BL
# 119185    2021-11-28           QA
# 135216    2021-11-28           SG
# 88517     2021-11-28           MV
# 156823    2021-11-28           AE
# 48788     2021-11-28           FO
# 21605     2021-11-28           BN
# 103851    2021-11-28           NZ
# 108730    2021-11-28           NO
# 108033    2021-11-28           MP
# 36939     2021-11-28           CY
# 11150     2021-11-28           BH
# 96184     2021-11-28           MN
# 133822    2021-11-28           SC
# 74577     2021-11-28           JE
#
#                                                Country WHO_region  New_cases  \
# 27181                                   Cayman Islands       AMRO        139
# ...

# %%
plt.figure(figsize=(30,10))
ax = sns.lineplot(data=chosen_cases,
            x="Date_reported",
            y="Hospital Service Weakness",
            hue="Country",
            size="Country"
            )
plt.xticks(rotation=45)
ax.set_xlabel("Date_reported",fontsize=30)
ax.set_ylabel("New_cases",fontsize=30)
ax.set_title("Cumulative Death/Cases Ratio", fontsize=30)
plt.show()

# %%
turkey_oct = turkey_cases[(turkey_cases["Date_reported"]>="2020-09-27")&(turkey_cases["Date_reported"]<"2020-11-01")]

# %%
turkey_oct
# Out:
#        Date_reported Country_code Country WHO_region  New_cases  \
# 152214    2020-09-27           TR  Turkey       EURO       8241
# 152215    2020-09-28           TR  Turkey       EURO       8197
# 152216    2020-09-29           TR  Turkey       EURO       8142
# 152217    2020-09-30           TR  Turkey       EURO       8157
# 152218    2020-10-01           TR  Turkey       EURO       8121
# 152219    2020-10-02           TR  Turkey       EURO       8137
# 152220    2020-10-03           TR  Turkey       EURO       8172
# 152221    2020-10-04           TR  Turkey       EURO       8232
# 152222    2020-10-05           TR  Turkey       EURO       8159
# 152223    2020-10-06           TR  Turkey       EURO       8333
# 152224    2020-10-07           TR  Turkey       EURO       8241
# 152225    2020-10-08           TR  Turkey       EURO       8311
# 152226    2020-10-09           TR  Turkey       EURO       8345
# 152227    2020-10-10           TR  Turkey       EURO       8359
# ...

# %%
turkey_nov = turkey_cases[(turkey_cases["Date_reported"]>="2020-11-01")&(turkey_cases["Date_reported"]<"2020-12-01")]

# %%
turkey_nov
# Out:
#        Date_reported Country_code Country WHO_region  New_cases  \
# 152249    2020-11-01           TR  Turkey       EURO       8943
# 152250    2020-11-02           TR  Turkey       EURO       8836
# 152251    2020-11-03           TR  Turkey       EURO       9032
# 152252    2020-11-04           TR  Turkey       EURO       9073
# 152253    2020-11-05           TR  Turkey       EURO       9121
# 152254    2020-11-06           TR  Turkey       EURO       9041
# 152255    2020-11-07           TR  Turkey       EURO       9166
# 152256    2020-11-08           TR  Turkey       EURO       9213
# 152257    2020-11-09           TR  Turkey       EURO       9246
# 152258    2020-11-10           TR  Turkey       EURO       9306
# 152259    2020-11-11           TR  Turkey       EURO       9259
# 152260    2020-11-12           TR  Turkey       EURO       9423
# 152261    2020-11-13           TR  Turkey       EURO       9571
# 152262    2020-11-14           TR  Turkey       EURO       9775
# ...

# %%
vaccination
# Out:
#                COUNTRY ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  \
# 0          Afghanistan  AFG       EMRO   REPORTING   2021-11-28
# 1              Albania  ALB       EURO   REPORTING   2021-11-21
# 2              Algeria  DZA       AFRO   REPORTING   2021-11-24
# 3       American Samoa  ASM       WPRO   REPORTING   2021-11-24
# 4              Andorra  AND       EURO   REPORTING   2021-10-31
# ..                 ...  ...        ...         ...          ...
# 223           Viet Nam  VNM       WPRO   REPORTING   2021-11-18
# 224  Wallis and Futuna  WLF       WPRO   REPORTING   2021-11-23
# 225              Yemen  YEM       EMRO   REPORTING   2021-11-28
# 226             Zambia  ZMB       AFRO   REPORTING   2021-11-18
# 227           Zimbabwe  ZWE       AFRO   REPORTING   2021-11-23
#
#      TOTAL_VACCINATIONS  PERSONS_VACCINATED_1PLUS_DOSE  \
# 0               4396007                      3896787.0
# 1               2006988                      1064233.0
# ...

# %%
df_general.groupby(["WHO_region"]).mean()
# Out:
#               New_cases  Cumulative_cases  New_deaths  Cumulative_deaths  \
# WHO_region
# AFRO         179.774118      4.651174e+04    4.383156        1113.458106
# AMRO        2476.191971      6.838686e+05   60.123719       18443.178085
# EMRO        1093.259945      2.717091e+05   20.172036        5518.942089
# EURO        2000.428681      4.733727e+05   35.715301       10219.896006
# Other          1.096126      6.980258e+02    0.018651          11.691535
# SEARO       5809.788574      1.446676e+06   92.162906       21756.234903
# WPRO         417.961549      6.560465e+04    5.797090        1000.576102
#
#             Hospital Service Weakness
# WHO_region
# AFRO                         0.020942
# AMRO                              inf
# EMRO                         0.033284
# EURO                         0.024180
# Other                        0.016457
# SEARO                        0.013189
# WPRO                         0.013540

# %%
vaccination.groupby(["WHO_REGION"]).mean()
# Out:
#             TOTAL_VACCINATIONS  PERSONS_VACCINATED_1PLUS_DOSE  \
# WHO_REGION
# AFRO              2.871214e+06                   1.888853e+06
# AMRO              2.582943e+07                   1.425795e+07
# EMRO              2.035822e+07                   1.302713e+07
# EURO              1.865588e+07                   9.553512e+06
# OTHER             5.046900e+04                   2.566100e+04
# SEARO             1.663230e+08                   1.051594e+08
# WPRO              8.681080e+07                   4.239811e+07
#
#             TOTAL_VACCINATIONS_PER100  PERSONS_VACCINATED_1PLUS_DOSE_PER100  \
# WHO_REGION
# AFRO                        28.446532                             17.593319
# AMRO                       111.920906                             57.805750
# EMRO                        73.313182                             33.584789
# EURO                       119.565350                             60.574949
# ...

# %%
vaccination.shape
# Out:
# (228, 14)

# %%
df_daily.shape
# Out:
# (165189, 8)

# %%
vaccination
# Out:
#                COUNTRY ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  \
# 0          Afghanistan  AFG       EMRO   REPORTING   2021-11-28
# 1              Albania  ALB       EURO   REPORTING   2021-11-21
# 2              Algeria  DZA       AFRO   REPORTING   2021-11-24
# 3       American Samoa  ASM       WPRO   REPORTING   2021-11-24
# 4              Andorra  AND       EURO   REPORTING   2021-10-31
# ..                 ...  ...        ...         ...          ...
# 223           Viet Nam  VNM       WPRO   REPORTING   2021-11-18
# 224  Wallis and Futuna  WLF       WPRO   REPORTING   2021-11-23
# 225              Yemen  YEM       EMRO   REPORTING   2021-11-28
# 226             Zambia  ZMB       AFRO   REPORTING   2021-11-18
# 227           Zimbabwe  ZWE       AFRO   REPORTING   2021-11-23
#
#      TOTAL_VACCINATIONS  PERSONS_VACCINATED_1PLUS_DOSE  \
# 0               4396007                      3896787.0
# 1               2006988                      1064233.0
# ...

# %%
df_daily
# Out:
#        Date_reported Country_code      Country WHO_region  New_cases  \
# 0         2020-01-03           AF  Afghanistan       EMRO          0
# 1         2020-01-04           AF  Afghanistan       EMRO          0
# 2         2020-01-05           AF  Afghanistan       EMRO          0
# 3         2020-01-06           AF  Afghanistan       EMRO          0
# 4         2020-01-07           AF  Afghanistan       EMRO          0
# ...              ...          ...          ...        ...        ...
# 165184    2021-11-25           ZW     Zimbabwe       AFRO         40
# 165185    2021-11-26           ZW     Zimbabwe       AFRO         27
# 165186    2021-11-27           ZW     Zimbabwe       AFRO         62
# 165187    2021-11-28           ZW     Zimbabwe       AFRO        115
# 165188    2021-11-29           ZW     Zimbabwe       AFRO         40
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 0                      0           0                  0
# ...

# %%
df_daily_updated = df_daily[(df_daily["Cases - cumulative total"]>0)&(df_daily["Deaths - cumulative total"]>0)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Cases - cumulative total'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-85-0cfdbed4aab9> in <module>
# ...

# %%
df_daily_updated

# %%
df_general[df_general["Date_reported"]=="2021-11-29"]

# %%
last = df_general[df_general["Date_reported"]=="2021-11-29"]

# %%
last.sort_values("Cumulative_cases", ascending=False).head(10)
# Out:
#        Date_reported Country_code                     Country WHO_region  \
# 158218    2021-11-29           US    United States of America       AMRO
# 67608     2021-11-29           IN                       India      SEARO
# 20212     2021-11-29           BR                      Brazil       AMRO
# 147763    2021-11-29           GB          The United Kingdom       EURO
# 122671    2021-11-29           RU          Russian Federation       EURO
# 152642    2021-11-29           TR                      Turkey       EURO
# 50880     2021-11-29           FR                      France       EURO
# 69002     2021-11-29           IR  Iran (Islamic Republic of)       EMRO
# 55062     2021-11-29           DE                     Germany       EURO
# 6272      2021-11-29           AR                   Argentina       AMRO
#
#         New_cases  Cumulative_cases  New_deaths  Cumulative_deaths  \
# 158218          0          47837599           0             771919
# ...

# %%
last.sort_values("Cumulative_deaths", ascending=False).head(20)
# Out:
#        Date_reported Country_code                     Country WHO_region  \
# 158218    2021-11-29           US    United States of America       AMRO
# 20212     2021-11-29           BR                      Brazil       AMRO
# 67608     2021-11-29           IN                       India      SEARO
# 94094     2021-11-29           MX                      Mexico       AMRO
# 122671    2021-11-29           RU          Russian Federation       EURO
# 115004    2021-11-29           PE                        Peru       AMRO
# 147763    2021-11-29           GB          The United Kingdom       EURO
# 68305     2021-11-29           ID                   Indonesia      SEARO
# 72487     2021-11-29           IT                       Italy       EURO
# 69002     2021-11-29           IR  Iran (Islamic Republic of)       EMRO
# 30667     2021-11-29           CO                    Colombia       AMRO
# 6272      2021-11-29           AR                   Argentina       AMRO
# ...

# %%
last.sort_values("Hospital Service Weakness", ascending=False).head(20)
# Out:
#        Date_reported Country_code                           Country  \
# 163794    2021-11-29           YE                             Yemen
# 115004    2021-11-29           PE                              Peru
# 94094     2021-11-29           MX                            Mexico
# 142884    2021-11-29           SD                             Sudan
# 42516     2021-11-29           EC                           Ecuador
# 139399    2021-11-29           SO                           Somalia
# 145672    2021-11-29           SY              Syrian Arab Republic
# 43213     2021-11-29           EG                             Egypt
# 82942     2021-11-29           LR                           Liberia
# 696       2021-11-29           AF                       Afghanistan
# 18818     2021-11-29           BA            Bosnia and Herzegovina
# 29970     2021-11-29           CN                             China
# 22303     2021-11-29           BG                          Bulgaria
# ...

# %%
del df_general["Hospital Service Weakness"]

# %%
df_general["Health System Power Index"] = df_general["New_cases"]/df_general["New_deaths"]

# %%
df_general
# Out:
#        Date_reported Country_code      Country WHO_region  New_cases  \
# 0         2020-01-03           AF  Afghanistan       EMRO          0
# 1         2020-01-04           AF  Afghanistan       EMRO          0
# 2         2020-01-05           AF  Afghanistan       EMRO          0
# 3         2020-01-06           AF  Afghanistan       EMRO          0
# 4         2020-01-07           AF  Afghanistan       EMRO          0
# ...              ...          ...          ...        ...        ...
# 165184    2021-11-25           ZW     Zimbabwe       AFRO         40
# 165185    2021-11-26           ZW     Zimbabwe       AFRO         27
# 165186    2021-11-27           ZW     Zimbabwe       AFRO         62
# 165187    2021-11-28           ZW     Zimbabwe       AFRO        115
# 165188    2021-11-29           ZW     Zimbabwe       AFRO         40
#
#         Cumulative_cases  New_deaths  Cumulative_deaths  \
# 0                      0           0                  0
# ...

# %%
df_general_out_nan = df_general[(df_general["New_cases"]!=0)&(df_general["New_deaths"]!=0)]

# %%
df_general_out_nan
# Out:
#        Date_reported Country_code      Country WHO_region  New_cases  \
# 80        2020-03-23           AF  Afghanistan       EMRO          6
# 83        2020-03-26           AF  Afghanistan       EMRO          6
# 86        2020-03-29           AF  Afghanistan       EMRO          8
# 91        2020-04-03           AF  Afghanistan       EMRO         34
# 93        2020-04-05           AF  Afghanistan       EMRO         29
# ...              ...          ...          ...        ...        ...
# 165176    2021-11-17           ZW     Zimbabwe       AFRO         34
# 165177    2021-11-18           ZW     Zimbabwe       AFRO         52
# 165183    2021-11-24           ZW     Zimbabwe       AFRO         33
# 165185    2021-11-26           ZW     Zimbabwe       AFRO         27
# 165187    2021-11-28           ZW     Zimbabwe       AFRO        115
#
#         Cumulative_cases  New_deaths  Cumulative_deaths  \
# 80                    40           1                  1
# ...

# %%
general_grouped_country = df_general_out_nan.groupby(["Country"]).mean()

# %%
general_grouped_country
# Out:
#                                                      New_cases  \
# Country
# Afghanistan                                         306.734000
# Albania                                             404.456612
# Algeria                                             359.197256
# Andorra                                              53.551724
# Angola                                              138.870159
# ...                                                        ...
# Wallis and Futuna                                     7.833333
# Yemen                                                26.527778
# Zambia                                              596.167665
# Zimbabwe                                            347.648649
# occupied Palestinian territory, including east ...  920.128310
#
#                                                     Cumulative_cases  \
# Country
# Afghanistan                                             71456.074000
# ...

# %%
best_health_systems = general_grouped_country.sort_values("Health System Power Index", ascending=False)

# %%
best_health_systems_head_1 = best_health_systems.head(20)

# %%
best_health_systems_head_1
# Out:
#                                      New_cases  Cumulative_cases  New_deaths  \
# Country
# Netherlands                        4248.254967      9.461832e+05   31.981788
# United Arab Emirates               1320.075229      3.429194e+05    3.933945
# Lao People's Democratic Republic    711.283582      3.652188e+04    2.373134
# Singapore                          1626.860656      1.172199e+05    5.745902
# Denmark                             890.050549      1.753618e+05    6.312088
# Qatar                               548.934615      1.473276e+05    2.350000
# The United Kingdom                16175.803828      3.238511e+06  230.886762
# Mongolia                           1530.302521      1.752904e+05    8.025210
# Bahrain                             664.891429      1.214549e+05    3.982857
# Switzerland                        1793.159176      4.392836e+05   20.662921
# France                            11912.450567      3.194174e+06  188.696921
# ...

# %%
best_health_systems = best_health_systems[best_health_systems["Cumulative_cases"]>40000]

# %%
best_health_systems[:20]
# Out:
#                          New_cases  Cumulative_cases  New_deaths  \
# Country
# Netherlands            4248.254967      9.461832e+05   31.981788
# United Arab Emirates   1320.075229      3.429194e+05    3.933945
# Singapore              1626.860656      1.172199e+05    5.745902
# Denmark                 890.050549      1.753618e+05    6.312088
# Qatar                   548.934615      1.473276e+05    2.350000
# The United Kingdom    16175.803828      3.238511e+06  230.886762
# Mongolia               1530.302521      1.752904e+05    8.025210
# Bahrain                 664.891429      1.214549e+05    3.982857
# Switzerland            1793.159176      4.392836e+05   20.662921
# France                11912.450567      3.194174e+06  188.696921
# Norway                  455.267544      7.173849e+04    4.605263
# Malaysia               5408.107660      7.280125e+05   62.751553
# Kuwait                  762.875240      1.962672e+05    4.731286
# ...

# %%
best_health_systems = general_grouped_country.sort_values("Health System Power Index", ascending=False)

# %%
best_health_systems = best_health_systems[best_health_systems["Cumulative_cases"]>100000]

# %%
best_health_systems.head(21)
# Out:
#                          New_cases  Cumulative_cases  New_deaths  \
# Country
# Netherlands            4248.254967      9.461832e+05   31.981788
# United Arab Emirates   1320.075229      3.429194e+05    3.933945
# Singapore              1626.860656      1.172199e+05    5.745902
# Denmark                 890.050549      1.753618e+05    6.312088
# Qatar                   548.934615      1.473276e+05    2.350000
# The United Kingdom    16175.803828      3.238511e+06  230.886762
# Mongolia               1530.302521      1.752904e+05    8.025210
# Bahrain                 664.891429      1.214549e+05    3.982857
# Switzerland            1793.159176      4.392836e+05   20.662921
# France                11912.450567      3.194174e+06  188.696921
# Malaysia               5408.107660      7.280125e+05   62.751553
# Kuwait                  762.875240      1.962672e+05    4.731286
# Republic of Korea       770.994709      1.185833e+05    6.313933
# ...

# %%
best_health_systems_head_1
# Out:
#                                      New_cases  Cumulative_cases  New_deaths  \
# Country
# Netherlands                        4248.254967      9.461832e+05   31.981788
# United Arab Emirates               1320.075229      3.429194e+05    3.933945
# Lao People's Democratic Republic    711.283582      3.652188e+04    2.373134
# Singapore                          1626.860656      1.172199e+05    5.745902
# Denmark                             890.050549      1.753618e+05    6.312088
# Qatar                               548.934615      1.473276e+05    2.350000
# The United Kingdom                16175.803828      3.238511e+06  230.886762
# Mongolia                           1530.302521      1.752904e+05    8.025210
# Bahrain                             664.891429      1.214549e+05    3.982857
# Switzerland                        1793.159176      4.392836e+05   20.662921
# France                            11912.450567      3.194174e+06  188.696921
# ...

# %%
best_health_systems.loc[["India"]]
# Out:
#             New_cases  Cumulative_cases  New_deaths  Cumulative_deaths  \
# Country
# India    55685.217391      1.474039e+07   754.89533      197823.784219
#
#          Health System Power Index
# Country
# India                    77.706316

# %%
df_daily.loc[["Ghana"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-107-cf86d5dfbac0> in <module>
# ----> 1 df_daily.loc[["Ghana"]]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1111                     raise ValueError("Cannot index with multidimensional key")
#    1112
# -> 1113                 return self._getitem_iterable(key, axis=axis)
#    1114
#    1115             # nested tuple slicing
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_iterable(self, key, axis)
#    1051
# ...

# %%
df_daily
# Out:
#        Date_reported Country_code      Country WHO_region  New_cases  \
# 0         2020-01-03           AF  Afghanistan       EMRO          0
# 1         2020-01-04           AF  Afghanistan       EMRO          0
# 2         2020-01-05           AF  Afghanistan       EMRO          0
# 3         2020-01-06           AF  Afghanistan       EMRO          0
# 4         2020-01-07           AF  Afghanistan       EMRO          0
# ...              ...          ...          ...        ...        ...
# 165184    2021-11-25           ZW     Zimbabwe       AFRO         40
# 165185    2021-11-26           ZW     Zimbabwe       AFRO         27
# 165186    2021-11-27           ZW     Zimbabwe       AFRO         62
# 165187    2021-11-28           ZW     Zimbabwe       AFRO        115
# 165188    2021-11-29           ZW     Zimbabwe       AFRO         40
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 0                      0           0                  0
# ...

# %%
df_general
# Out:
#        Date_reported Country_code      Country WHO_region  New_cases  \
# 0         2020-01-03           AF  Afghanistan       EMRO          0
# 1         2020-01-04           AF  Afghanistan       EMRO          0
# 2         2020-01-05           AF  Afghanistan       EMRO          0
# 3         2020-01-06           AF  Afghanistan       EMRO          0
# 4         2020-01-07           AF  Afghanistan       EMRO          0
# ...              ...          ...          ...        ...        ...
# 165184    2021-11-25           ZW     Zimbabwe       AFRO         40
# 165185    2021-11-26           ZW     Zimbabwe       AFRO         27
# 165186    2021-11-27           ZW     Zimbabwe       AFRO         62
# 165187    2021-11-28           ZW     Zimbabwe       AFRO        115
# 165188    2021-11-29           ZW     Zimbabwe       AFRO         40
#
#         Cumulative_cases  New_deaths  Cumulative_deaths  \
# 0                      0           0                  0
# ...

# %%
last[last["Cumulative_cases"]<50000].iloc[100:]
# Out:
#        Date_reported Country_code                       Country WHO_region  \
# 153339    2021-11-29           TM                  Turkmenistan       EURO
# 154036    2021-11-29           TC      Turks and Caicos Islands       AMRO
# 154733    2021-11-29           TV                        Tuvalu       WPRO
# 157521    2021-11-29           TZ   United Republic of Tanzania       AFRO
# 158915    2021-11-29           VI  United States Virgin Islands       AMRO
# 161006    2021-11-29           VU                       Vanuatu       WPRO
# 163097    2021-11-29           WF             Wallis and Futuna       WPRO
# 163794    2021-11-29           YE                         Yemen       EMRO
#
#         New_cases  Cumulative_cases  New_deaths  Cumulative_deaths  \
# 153339          0                 0           0                  0
# 154036          0              3096           0                 24
# 154733          0                 0           0                  0
# ...

# %%
vaccination
# Out:
#                COUNTRY ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  \
# 0          Afghanistan  AFG       EMRO   REPORTING   2021-11-28
# 1              Albania  ALB       EURO   REPORTING   2021-11-21
# 2              Algeria  DZA       AFRO   REPORTING   2021-11-24
# 3       American Samoa  ASM       WPRO   REPORTING   2021-11-24
# 4              Andorra  AND       EURO   REPORTING   2021-10-31
# ..                 ...  ...        ...         ...          ...
# 223           Viet Nam  VNM       WPRO   REPORTING   2021-11-18
# 224  Wallis and Futuna  WLF       WPRO   REPORTING   2021-11-23
# 225              Yemen  YEM       EMRO   REPORTING   2021-11-28
# 226             Zambia  ZMB       AFRO   REPORTING   2021-11-18
# 227           Zimbabwe  ZWE       AFRO   REPORTING   2021-11-23
#
#      TOTAL_VACCINATIONS  PERSONS_VACCINATED_1PLUS_DOSE  \
# 0               4396007                      3896787.0
# 1               2006988                      1064233.0
# ...

# %%
vaccination["pfizer"] = vaccination["VACCINES_USED"].str.contains("Pfizer")

# %%
vaccination.columns
# Out:
# Index(['COUNTRY', 'ISO3', 'WHO_REGION', 'DATA_SOURCE', 'DATE_UPDATED',
#        'TOTAL_VACCINATIONS', 'PERSONS_VACCINATED_1PLUS_DOSE',
#        'TOTAL_VACCINATIONS_PER100', 'PERSONS_VACCINATED_1PLUS_DOSE_PER100',
#        'PERSONS_FULLY_VACCINATED', 'PERSONS_FULLY_VACCINATED_PER100',
#        'VACCINES_USED', 'FIRST_VACCINE_DATE', 'NUMBER_VACCINES_TYPES_USED',
#        'pfizer'],
#       dtype='object')

# %%
df_daily
# Out:
#        Date_reported Country_code      Country WHO_region  New_cases  \
# 0         2020-01-03           AF  Afghanistan       EMRO          0
# 1         2020-01-04           AF  Afghanistan       EMRO          0
# 2         2020-01-05           AF  Afghanistan       EMRO          0
# 3         2020-01-06           AF  Afghanistan       EMRO          0
# 4         2020-01-07           AF  Afghanistan       EMRO          0
# ...              ...          ...          ...        ...        ...
# 165184    2021-11-25           ZW     Zimbabwe       AFRO         40
# 165185    2021-11-26           ZW     Zimbabwe       AFRO         27
# 165186    2021-11-27           ZW     Zimbabwe       AFRO         62
# 165187    2021-11-28           ZW     Zimbabwe       AFRO        115
# 165188    2021-11-29           ZW     Zimbabwe       AFRO         40
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 0                      0           0                  0
# ...

# %%
vaccination_index = vaccination.set_index("COUNTRY")

# %%
pfizer_daily = vaccination_index["pfizer"].append(df_daily["Deaths - cumulative total per 100000 population"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Deaths - cumulative total per 100000 population'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-116-63201ba33844> in <module>
# ...

# %%
pfizer_daily = pd.DataFrame(pfizer_daily)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-117-fb3e32474436> in <module>
# ----> 1 pfizer_daily = pd.DataFrame(pfizer_daily)
#
# NameError: name 'pfizer_daily' is not defined

# %%
pfizer_daily.loc["Afghanistan"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-118-3ac828ac08f6> in <module>
# ----> 1 pfizer_daily.loc["Afghanistan"]
#
# NameError: name 'pfizer_daily' is not defined

# %%
df_daily
# Out:
#        Date_reported Country_code      Country WHO_region  New_cases  \
# 0         2020-01-03           AF  Afghanistan       EMRO          0
# 1         2020-01-04           AF  Afghanistan       EMRO          0
# 2         2020-01-05           AF  Afghanistan       EMRO          0
# 3         2020-01-06           AF  Afghanistan       EMRO          0
# 4         2020-01-07           AF  Afghanistan       EMRO          0
# ...              ...          ...          ...        ...        ...
# 165184    2021-11-25           ZW     Zimbabwe       AFRO         40
# 165185    2021-11-26           ZW     Zimbabwe       AFRO         27
# 165186    2021-11-27           ZW     Zimbabwe       AFRO         62
# 165187    2021-11-28           ZW     Zimbabwe       AFRO        115
# 165188    2021-11-29           ZW     Zimbabwe       AFRO         40
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 0                      0           0                  0
# ...

# %%
last[last["Country"]=="United States of America"]
# Out:
#        Date_reported Country_code                   Country WHO_region  \
# 158218    2021-11-29           US  United States of America       AMRO
#
#         New_cases  Cumulative_cases  New_deaths  Cumulative_deaths  \
# 158218          0          47837599           0             771919
#
#         Hospital Service Weakness
# 158218                   0.016136

# %%
last
# Out:
#        Date_reported Country_code            Country WHO_region  New_cases  \
# 696       2021-11-29           AF        Afghanistan       EMRO         28
# 1393      2021-11-29           AL            Albania       EURO        418
# 2090      2021-11-29           DZ            Algeria       AFRO        172
# 2787      2021-11-29           AS     American Samoa       WPRO          0
# 3484      2021-11-29           AD            Andorra       EURO          0
# ...              ...          ...                ...        ...        ...
# 162400    2021-11-29           VN           Viet Nam       WPRO      12936
# 163097    2021-11-29           WF  Wallis and Futuna       WPRO          0
# 163794    2021-11-29           YE              Yemen       EMRO          6
# 164491    2021-11-29           ZM             Zambia       AFRO          5
# 165188    2021-11-29           ZW           Zimbabwe       AFRO         40
#
#         Cumulative_cases  New_deaths  Cumulative_deaths  \
# ...

# %%
vaccination_index.shape
# Out:
# (228, 14)

# %%
pfizer = vaccination[vaccination["pfizer"]==True]

# %%
vaccination[vaccination["COUNTRY"]=="India"]
# Out:
#    COUNTRY ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  TOTAL_VACCINATIONS  \
# 94   India  IND      SEARO   REPORTING   2021-11-23          1183573646
#
#     PERSONS_VACCINATED_1PLUS_DOSE  TOTAL_VACCINATIONS_PER100  \
# 94                    770622080.0                     85.766
#
#     PERSONS_VACCINATED_1PLUS_DOSE_PER100  PERSONS_FULLY_VACCINATED  \
# 94                                55.842               412951566.0
#
#     PERSONS_FULLY_VACCINATED_PER100  \
# 94                           29.924
#
#                                         VACCINES_USED FIRST_VACCINE_DATE  \
# 94  Bharat - Covaxin,Gamaleya - Gam-Covid-Vac,Jans...         2021-01-16
#
#     NUMBER_VACCINES_TYPES_USED pfizer
# 94                         5.0  False

# %%
vaccination.sort_values("FIRST_VACCINE_DATE", ascending=True).head(13)
# Out:
#                                             COUNTRY ISO3 WHO_REGION  \
# 43                                            China  CHN       WPRO
# 15                                          Bahrain  BHR       EMRO
# 112                Lao People's Democratic Republic  LAO       WPRO
# 38                                           Canada  CAN       AMRO
# 218                        United States of America  USA       AMRO
# 216                            United Arab Emirates  ARE       EMRO
# 100                                          Israel  ISR       EURO
# 56                                          Denmark  DNK       EURO
# 151  Northern Mariana Islands (Commonwealth of the)  MNP       WPRO
# 3                                    American Samoa  ASM       WPRO
# 42                                            Chile  CHL       AMRO
# 203                              The United Kingdom  GBR       EURO
# 126                                           Malta  MLT       EURO
#
# ...

# %%
vac_early = vaccination[(vaccination["COUNTRY"]=="China")|(vaccination["COUNTRY"]=="Bahrain")|(vaccination["COUNTRY"]=="Canada")|(vaccination["COUNTRY"]=="United Arab Emirates")|(vaccination["COUNTRY"]=="United States of America")|(vaccination["COUNTRY"]=="Israel")|(vaccination["COUNTRY"]=="Denmark")|(vaccination["COUNTRY"]=="Chile")|(vaccination["COUNTRY"]=="The United Kingdom")|(vaccination["COUNTRY"]=="Germany")]

# %%
vac_early = vac_early.sort_values("FIRST_VACCINE_DATE", ascending=True)

# %%
plt.figure(figsize=(10,10))
ax = sns.scatterplot(data=vac_early,
            x="FIRST_VACCINE_DATE",
            y="COUNTRY",
            hue="WHO_REGION"
            )
plt.xticks(rotation=45)
ax.set_xlabel("Vaccination Start Date",fontsize=20)
ax.set_ylabel("Earliest Countries",fontsize=20)
plt.show()

# %%
impact_vaccine = df_general[(df_general["Date_reported"]>"2020-07-21")&(df_general["Date_reported"]<"2021-01-21")&(df_general["Country"]=="China")|(df_general["Date_reported"]>"2020-11-04")&(df_general["Date_reported"]<"2021-05-04")&(df_general["Country"]=="Bahrain")|(df_general["Date_reported"]>"2020-12-14")&(df_general["Date_reported"]<"2021-06-14")&(df_general["Country"]=="United States of America")|(df_general["Date_reported"]>"2020-12-14")&(df_general["Date_reported"]<"2021-06-14")&(df_general["Country"]=="Canada")|(df_general["Date_reported"]>"2020-12-14")&(df_general["Date_reported"]<"2021-06-14")&(df_general["Country"]=="United Arab Emirates")|(df_general["Date_reported"]>"2020-12-16")&(df_general["Date_reported"]<"2021-06-16")&(df_general["Country"]=="Israel")|(df_general["Date_reported"]>"2020-12-16")&(df_general["Date_reported"]<"2021-06-16")&(df_general["Country"]=="Denmark")|(df_general["Date_reported"]>"2020-12-21")&(df_general["Date_reported"]<"2021-06-21")&(df_general["Country"]=="The United Kingdom")|(df_general["Date_reported"]>"2020-12-21")&(df_general["Date_reported"]<"2021-06-21")&(df_general["Country"]=="Chile")|(df_general["Date_reported"]>"2020-12-23")&(df_general["Date_reported"]<"2021-06-23")&(df_general["Country"]=="Germany")]

# %%
plt.figure(figsize=(40,20))
ax = sns.lineplot(data=impact_vaccine,
            x="Date_reported",
            y="New_deaths",
            hue="Country",palette="Paired"
            )
plt.xticks(rotation=45)
ax.set_xlabel("Date_reported",fontsize=30)
ax.set_ylabel(" DAILY NEW DEATH NUMBERS ",fontsize=30)
ax.set_title("Impact of Vaccines on Death Numbers", fontsize=40)
ax.tick_params(labelsize=25)
plt.setp(ax.get_legend().get_texts(), fontsize='30')
plt.setp(ax.get_legend().get_title(), fontsize='32')
plt.show()

# %%
df_general.sample(1)
# Out:
#      Date_reported Country_code  Country WHO_region  New_cases  \
# 8905    2021-06-27           AT  Austria       EURO        117
#
#       Cumulative_cases  New_deaths  Cumulative_deaths  \
# 8905            645655           0              10503
#
#       Health System Power Index
# 8905                        inf

# %%
impact_vaccine
# Out:
#        Date_reported Country_code                   Country WHO_region  \
# 10762     2020-11-05           BH                   Bahrain       EMRO
# 10763     2020-11-06           BH                   Bahrain       EMRO
# 10764     2020-11-07           BH                   Bahrain       EMRO
# 10765     2020-11-08           BH                   Bahrain       EMRO
# 10766     2020-11-09           BH                   Bahrain       EMRO
# ...              ...          ...                       ...        ...
# 158045    2021-06-09           US  United States of America       AMRO
# 158046    2021-06-10           US  United States of America       AMRO
# 158047    2021-06-11           US  United States of America       AMRO
# 158048    2021-06-12           US  United States of America       AMRO
# 158049    2021-06-13           US  United States of America       AMRO
#
#         New_cases  Cumulative_cases  New_deaths  Cumulative_deaths  \
# ...

# %%
last.sort_values("Cumulative_deaths", ascending=False)
# Out:
#        Date_reported Country_code                      Country WHO_region  \
# 158218    2021-11-29           US     United States of America       AMRO
# 20212     2021-11-29           BR                       Brazil       AMRO
# 67608     2021-11-29           IN                        India      SEARO
# 94094     2021-11-29           MX                       Mexico       AMRO
# 122671    2021-11-29           RU           Russian Federation       EURO
# ...              ...          ...                          ...        ...
# 129641    2021-11-29           WS                        Samoa       WPRO
# 138702    2021-11-29           SB              Solomon Islands       WPRO
# 77366     2021-11-29           KI                     Kiribati       WPRO
# 48092     2021-11-29           FK  Falkland Islands (Malvinas)       AMRO
# 57850     2021-11-29           GL                    Greenland       EURO
#
#         New_cases  Cumulative_cases  New_deaths  Cumulative_deaths  \
# ...

# %%
most_5_death = df_general[(df_general["Country"]=="United States of America")|(df_general["Country"]=="Brazil")|(df_general["Country"]=="India")|(df_general["Country"]=="Mexico")|(df_general["Country"]=="Russian Federation")]

# %%
plt.figure(figsize=(40,20))
sns.set_theme()
ax = sns.barplot(data=worst_vac,
            x="COUNTRY",
            y="PERSONS_VACCINATED_1PLUS_DOSE_PER100",
            hue="WHO_REGION",
            palette="Paired",
            dodge=False
                )
plt.xticks(rotation=90)
ax.set_xlabel("COUNTRIES",fontsize=40)
ax.set_ylabel(" PERCENTAGE OF PEOPLE WHO GOT AT LEAST 1 DOSE OF VACCINE ",fontsize=30)
ax.set_title("100 COUNTRIES WHO GOT LOWEST RATE OF VACCINATION", fontsize=40)
ax.tick_params(labelsize=25)
plt.setp(ax.get_legend().get_texts(), fontsize='30')
plt.setp(ax.get_legend().get_title(), fontsize='32')

plt.show()

# %%
plt.figure(figsize=(30,20))
sns.set_theme()
ax = sns.boxplot(data=most_5_death,
            x="Country",
            y="New_deaths",
            hue="Country",palette="Paired"
            )

plt.xticks(rotation=45)
ax.set_xlabel("COUNTRIES",fontsize=20)
ax.set_ylabel(" DISTRIBUTION OF DAILY NEW DEATH NUMBERS ",fontsize=30)
ax.tick_params(labelsize=25)
plt.setp(ax.get_legend().get_texts(), fontsize='30')
plt.setp(ax.get_legend().get_title(), fontsize='32')
plt.show()

# %%
del last["Hospital Service Weakness"]

# %%
last["Health System Power Index"] = last["New_cases"]/last["New_deaths"]
# Out:
# <ipython-input-138-d8abe10aeb67>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   last["Health System Power Index"] = last["New_cases"]/last["New_deaths"]

# %%
region_group = df_general_out_nan.groupby(["WHO_region"]).mean()

# %%
region_group
# Out:
#                New_cases  Cumulative_cases  New_deaths  Cumulative_deaths  \
# WHO_region
# AFRO          590.325376      1.306125e+05   15.471556        3376.567960
# AMRO         6569.193443      1.793537e+06  159.750256       48447.571331
# EMRO         1632.550583      3.885987e+05   30.535862        8095.462557
# EURO         3430.587097      7.945554e+05   62.620045       17255.773991
# SEARO       12332.551791      3.066380e+06  196.225215       46161.514579
# WPRO         2284.639161      3.441590e+05   32.897203        5053.933100
#
#             Health System Power Index
# WHO_region
# AFRO                        59.314063
# AMRO                        64.783230
# EMRO                       102.239175
# EURO                       118.413569
# SEARO                       79.149469
# WPRO                       143.606905

# %%
vaccination
# Out:
#                COUNTRY ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  \
# 0          Afghanistan  AFG       EMRO   REPORTING   2021-11-28
# 1              Albania  ALB       EURO   REPORTING   2021-11-21
# 2              Algeria  DZA       AFRO   REPORTING   2021-11-24
# 3       American Samoa  ASM       WPRO   REPORTING   2021-11-24
# 4              Andorra  AND       EURO   REPORTING   2021-10-31
# ..                 ...  ...        ...         ...          ...
# 223           Viet Nam  VNM       WPRO   REPORTING   2021-11-18
# 224  Wallis and Futuna  WLF       WPRO   REPORTING   2021-11-23
# 225              Yemen  YEM       EMRO   REPORTING   2021-11-28
# 226             Zambia  ZMB       AFRO   REPORTING   2021-11-18
# 227           Zimbabwe  ZWE       AFRO   REPORTING   2021-11-23
#
#      TOTAL_VACCINATIONS  PERSONS_VACCINATED_1PLUS_DOSE  \
# 0               4396007                      3896787.0
# 1               2006988                      1064233.0
# ...

# %%
worst_vac = vaccination.sort_values("PERSONS_VACCINATED_1PLUS_DOSE_PER100", ascending=True).iloc[:100]

# %%
plt.figure(figsize=(40,20))
sns.set_theme()
ax = sns.barplot(data=worst_vac,
            x="COUNTRY",
            y="PERSONS_VACCINATED_1PLUS_DOSE_PER100",
            palette="Paired",
            hue="WHO_REGION"
                )
plt.xticks(rotation=90)
ax.set_xlabel("COUNTRIES",fontsize=40)
ax.set_ylabel(" PERCENTAGE OF PEOPLE WHO GOT AT LEAST 1 DOSE OF VACCINE ",fontsize=30)
ax.set_title("100 COUNTRIES WHO GOT LOWEST RATE OF VACCINATION", fontsize=40)
ax.tick_params(labelsize=25)

plt.show()

# %%
last
# Out:
#        Date_reported Country_code            Country WHO_region  New_cases  \
# 696       2021-11-29           AF        Afghanistan       EMRO         28
# 1393      2021-11-29           AL            Albania       EURO        418
# 2090      2021-11-29           DZ            Algeria       AFRO        172
# 2787      2021-11-29           AS     American Samoa       WPRO          0
# 3484      2021-11-29           AD            Andorra       EURO          0
# ...              ...          ...                ...        ...        ...
# 162400    2021-11-29           VN           Viet Nam       WPRO      12936
# 163097    2021-11-29           WF  Wallis and Futuna       WPRO          0
# 163794    2021-11-29           YE              Yemen       EMRO          6
# 164491    2021-11-29           ZM             Zambia       AFRO          5
# 165188    2021-11-29           ZW           Zimbabwe       AFRO         40
#
#         Cumulative_cases  New_deaths  Cumulative_deaths  \
# ...

# %%
vaccination[(vaccination["COUNTRY"]=="Bulgaria")]
# Out:
#      COUNTRY ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  TOTAL_VACCINATIONS  \
# 32  Bulgaria  BGR       EURO   REPORTING   2021-11-21             3189047
#
#     PERSONS_VACCINATED_1PLUS_DOSE  TOTAL_VACCINATIONS_PER100  \
# 32                      1832182.0                       45.9
#
#     PERSONS_VACCINATED_1PLUS_DOSE_PER100  PERSONS_FULLY_VACCINATED  \
# 32                                26.357                 1295027.0
#
#     PERSONS_FULLY_VACCINATED_PER100  \
# 32                           24.374
#
#                                         VACCINES_USED FIRST_VACCINE_DATE  \
# 32  AstraZeneca - Vaxzevria,Janssen - Ad26.COV 2-S...         2020-12-30
#
#     NUMBER_VACCINES_TYPES_USED pfizer
# 32                         4.0   True

# %%
last.sort_values("Health System Power Index",ascending=True).head(40)
# Out:
#        Date_reported Country_code                 Country WHO_region  \
# 62729     2021-11-29           GW           Guinea-Bissau       AFRO
# 114307    2021-11-29           PY                Paraguay       AMRO
# 115701    2021-11-29           PH             Philippines       WPRO
# 25091     2021-11-29           KH                Cambodia       WPRO
# 163794    2021-11-29           YE                   Yemen       EMRO
# 120580    2021-11-29           MD     Republic of Moldova       EURO
# 87124     2021-11-29           MW                  Malawi       AFRO
# 6969      2021-11-29           AM                 Armenia       EURO
# 18818     2021-11-29           BA  Bosnia and Herzegovina       EURO
# 94094     2021-11-29           MX                  Mexico       AMRO
# 22303     2021-11-29           BG                Bulgaria       EURO
# 121974    2021-11-29           RO                 Romania       EURO
# 143581    2021-11-29           SR                Suriname       AMRO
# ...

# %%
answer_six = last[(last["Country"]=="Paraguay")|(last["Country"]=="Bulgaria")|(last["Country"]=="Philippines")|(last["Country"]=="Mexico")|(last["Country"]=="Yemen")|(last["Country"]=="Romania")|(last["Country"]=="Syrian Arab Republic")|(last["Country"]=="Ukraine")|(last["Country"]=="Russian Federation")|(last["Country"]=="India")|(last["Country"]=="Brazil")]

# %%
answer_six = answer_six.sort_values("Health System Power Index")

# %%
answer_six
# Out:
#        Date_reported Country_code               Country WHO_region  New_cases  \
# 114307    2021-11-29           PY              Paraguay       AMRO        303
# 115701    2021-11-29           PH           Philippines       WPRO        838
# 163794    2021-11-29           YE                 Yemen       EMRO          6
# 94094     2021-11-29           MX                Mexico       AMRO       2956
# 22303     2021-11-29           BG              Bulgaria       EURO        728
# 121974    2021-11-29           RO               Romania       EURO       1377
# 145672    2021-11-29           SY  Syrian Arab Republic       EMRO        102
# 156127    2021-11-29           UA               Ukraine       EURO       5804
# 122671    2021-11-29           RU    Russian Federation       EURO      33860
# 67608     2021-11-29           IN                 India      SEARO       8309
# 20212     2021-11-29           BR                Brazil       AMRO       9233
#
# ...

# %%
last_index = last.groupby(["Country"]).mean()

# %%
last
# Out:
#        Date_reported Country_code            Country WHO_region  New_cases  \
# 696       2021-11-29           AF        Afghanistan       EMRO         28
# 1393      2021-11-29           AL            Albania       EURO        418
# 2090      2021-11-29           DZ            Algeria       AFRO        172
# 2787      2021-11-29           AS     American Samoa       WPRO          0
# 3484      2021-11-29           AD            Andorra       EURO          0
# ...              ...          ...                ...        ...        ...
# 162400    2021-11-29           VN           Viet Nam       WPRO      12936
# 163097    2021-11-29           WF  Wallis and Futuna       WPRO          0
# 163794    2021-11-29           YE              Yemen       EMRO          6
# 164491    2021-11-29           ZM             Zambia       AFRO          5
# 165188    2021-11-29           ZW           Zimbabwe       AFRO         40
#
#         Cumulative_cases  New_deaths  Cumulative_deaths  \
# ...

# %%
last_index.sort_values("Cumulative_deaths", ascending=False).head(10)
# Out:
#                             New_cases  Cumulative_cases  New_deaths  \
# Country
# United States of America            0          47837599           0
# Brazil                           9233          22076863         229
# India                            8309          34580832         236
# Mexico                           2956           3882792         245
# Russian Federation              33860           9604233        1209
# Peru                             1574           2232749          45
# The United Kingdom              36507          10146919          51
# Indonesia                         176           4256112          11
# Italy                           12927           5007818          47
# Iran (Islamic Republic of)       3781           6108882          80
#
#                             Cumulative_deaths  Health System Power Index
# Country
# United States of America               771919                        NaN
# ...

# %%
last["Cumulative_cases"].sum()-157606199
# Out:
# 103260812

# %%
last_index.sort_values("Cumulative_cases", ascending=False).head(10)
# Out:
#                             New_cases  Cumulative_cases  New_deaths  \
# Country
# United States of America            0          47837599           0
# India                            8309          34580832         236
# Brazil                           9233          22076863         229
# The United Kingdom              36507          10146919          51
# Russian Federation              33860           9604233        1209
# Turkey                          21655           8746055         213
# France                          31642           7388196          23
# Iran (Islamic Republic of)       3781           6108882          80
# Germany                         29364           5791060          73
# Argentina                           0           5325560           0
#
#                             Cumulative_deaths  Health System Power Index
# Country
# United States of America               771919                        NaN
# ...

# %%
df_general
# Out:
#        Date_reported Country_code      Country WHO_region  New_cases  \
# 0         2020-01-03           AF  Afghanistan       EMRO          0
# 1         2020-01-04           AF  Afghanistan       EMRO          0
# 2         2020-01-05           AF  Afghanistan       EMRO          0
# 3         2020-01-06           AF  Afghanistan       EMRO          0
# 4         2020-01-07           AF  Afghanistan       EMRO          0
# ...              ...          ...          ...        ...        ...
# 165184    2021-11-25           ZW     Zimbabwe       AFRO         40
# 165185    2021-11-26           ZW     Zimbabwe       AFRO         27
# 165186    2021-11-27           ZW     Zimbabwe       AFRO         62
# 165187    2021-11-28           ZW     Zimbabwe       AFRO        115
# 165188    2021-11-29           ZW     Zimbabwe       AFRO         40
#
#         Cumulative_cases  New_deaths  Cumulative_deaths  \
# 0                      0           0                  0
# ...

# %%
vaccination.head(1)
# Out:
#        COUNTRY ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  TOTAL_VACCINATIONS  \
# 0  Afghanistan  AFG       EMRO   REPORTING   2021-11-28             4396007
#
#    PERSONS_VACCINATED_1PLUS_DOSE  TOTAL_VACCINATIONS_PER100  \
# 0                      3896787.0                     11.293
#
#    PERSONS_VACCINATED_1PLUS_DOSE_PER100  PERSONS_FULLY_VACCINATED  \
# 0                                 10.01                 3564819.0
#
#    PERSONS_FULLY_VACCINATED_PER100  \
# 0                            9.157
#
#                                        VACCINES_USED FIRST_VACCINE_DATE  \
# 0  Beijing CNBG - BBIBP-CorV,Janssen - Ad26.COV 2...         2021-02-22
#
#    NUMBER_VACCINES_TYPES_USED pfizer
# 0                         4.0   True

# %%
general_grouped_country
# Out:
#                                                      New_cases  \
# Country
# Afghanistan                                         306.734000
# Albania                                             404.456612
# Algeria                                             359.197256
# Andorra                                              53.551724
# Angola                                              138.870159
# ...                                                        ...
# Wallis and Futuna                                     7.833333
# Yemen                                                26.527778
# Zambia                                              596.167665
# Zimbabwe                                            347.648649
# occupied Palestinian territory, including east ...  920.128310
#
#                                                     Cumulative_cases  \
# Country
# Afghanistan                                             71456.074000
# ...

# %%
211*697
# Out:
# 147067

# %%
vaccination
# Out:
#                COUNTRY ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  \
# 0          Afghanistan  AFG       EMRO   REPORTING   2021-11-28
# 1              Albania  ALB       EURO   REPORTING   2021-11-21
# 2              Algeria  DZA       AFRO   REPORTING   2021-11-24
# 3       American Samoa  ASM       WPRO   REPORTING   2021-11-24
# 4              Andorra  AND       EURO   REPORTING   2021-10-31
# ..                 ...  ...        ...         ...          ...
# 223           Viet Nam  VNM       WPRO   REPORTING   2021-11-18
# 224  Wallis and Futuna  WLF       WPRO   REPORTING   2021-11-23
# 225              Yemen  YEM       EMRO   REPORTING   2021-11-28
# 226             Zambia  ZMB       AFRO   REPORTING   2021-11-18
# 227           Zimbabwe  ZWE       AFRO   REPORTING   2021-11-23
#
#      TOTAL_VACCINATIONS  PERSONS_VACCINATED_1PLUS_DOSE  \
# 0               4396007                      3896787.0
# 1               2006988                      1064233.0
# ...

# %%
region_group_vac = vaccination.groupby(["WHO_REGION"]).mean("PERSONS_FULLY_VACCINATED_PER100").sort_values("PERSONS_FULLY_VACCINATED_PER100")

# %%
region_group_vac
# Out:
#             TOTAL_VACCINATIONS  PERSONS_VACCINATED_1PLUS_DOSE  \
# WHO_REGION
# AFRO              2.871214e+06                   1.888853e+06
# EMRO              2.035822e+07                   1.302713e+07
# SEARO             1.663230e+08                   1.051594e+08
# AMRO              2.582943e+07                   1.425795e+07
# EURO              1.865588e+07                   9.553512e+06
# WPRO              8.681080e+07                   4.239811e+07
# OTHER             5.046900e+04                   2.566100e+04
#
#             TOTAL_VACCINATIONS_PER100  PERSONS_VACCINATED_1PLUS_DOSE_PER100  \
# WHO_REGION
# AFRO                        28.446532                             17.593319
# EMRO                        73.313182                             33.584789
# SEARO                       96.294200                             53.860900
# AMRO                       111.920906                             57.805750
# ...

# %%
vaccination.sort_values("PERSONS_FULLY_VACCINATED_PER100", ascending= False).head(50)
# Out:
#                       COUNTRY ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  \
# 79                  Gibraltar  GIB       EURO        OWID   2021-11-24
# 156                     Palau  PLW       WPRO   REPORTING   2021-11-24
# 39             Cayman Islands  CYM       AMRO   REPORTING   2021-11-29
# 42                      Chile  CHL       AMRO   REPORTING   2021-11-29
# 165               Puerto Rico  PRI       AMRO   REPORTING   2021-11-29
# 126                     Malta  MLT       EURO   REPORTING   2021-11-21
# 164                  Portugal  PRT       EURO   REPORTING   2021-11-21
# 51                       Cuba  CUB       AMRO   REPORTING   2021-11-29
# 172                      Saba  XCA       AMRO   REPORTING   2021-11-29
# 183                Seychelles  SYC       AFRO   REPORTING   2021-11-29
# 185                 Singapore  SGP       WPRO   REPORTING   2021-11-19
# 36                   Cambodia  KHM       WPRO   REPORTING   2021-11-19
# ...

# %%
vaccination[vaccination["COUNTRY"]== "Gibraltar"]
# Out:
#       COUNTRY ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  TOTAL_VACCINATIONS  \
# 79  Gibraltar  GIB       EURO        OWID   2021-11-24               96771
#
#     PERSONS_VACCINATED_1PLUS_DOSE  TOTAL_VACCINATIONS_PER100  \
# 79                        40906.0                    287.231
#
#     PERSONS_VACCINATED_1PLUS_DOSE_PER100  PERSONS_FULLY_VACCINATED  \
# 79                               121.415                   39819.0
#
#     PERSONS_FULLY_VACCINATED_PER100                VACCINES_USED  \
# 79                          118.189  Pfizer BioNTech - Comirnaty
#
#    FIRST_VACCINE_DATE  NUMBER_VACCINES_TYPES_USED pfizer
# 79                NaN                         1.0   True

# %%
df_general_out_nan.sort_values("Health System Power Index").head(30)
# Out:
#        Date_reported Country_code                Country WHO_region  \
# 50786     2021-08-27           FR                 France       EURO
# 155369    2021-09-29           UG                 Uganda       AFRO
# 65196     2021-01-12           HN               Honduras       AMRO
# 50795     2021-09-05           FR                 France       EURO
# 1608      2020-08-04           DZ                Algeria       AFRO
# 44970     2020-12-30           ER                Eritrea       AFRO
# 42369     2021-07-05           EC                Ecuador       AMRO
# 11798     2021-10-10           BD             Bangladesh      SEARO
# 24300     2021-08-27           CV             Cabo Verde       AFRO
# 88962     2021-03-21           ML                   Mali       AFRO
# 155220    2021-05-03           UG                 Uganda       AFRO
# 105887    2021-10-04           NG                Nigeria       AFRO
# 99921     2020-09-09          NaN                Namibia       AFRO
# ...

# %%
a=df_general_out_nan[('New_cases')]  
for row,value in enumerate(a):
    if(value>0):
        value==value
    else:
        value=-value

# %%
df_general_out_nan.sort_values("Health System Power Index").head(30)
# Out:
#        Date_reported Country_code                Country WHO_region  \
# 50786     2021-08-27           FR                 France       EURO
# 155369    2021-09-29           UG                 Uganda       AFRO
# 65196     2021-01-12           HN               Honduras       AMRO
# 50795     2021-09-05           FR                 France       EURO
# 1608      2020-08-04           DZ                Algeria       AFRO
# 44970     2020-12-30           ER                Eritrea       AFRO
# 42369     2021-07-05           EC                Ecuador       AMRO
# 11798     2021-10-10           BD             Bangladesh      SEARO
# 24300     2021-08-27           CV             Cabo Verde       AFRO
# 88962     2021-03-21           ML                   Mali       AFRO
# 155220    2021-05-03           UG                 Uganda       AFRO
# 105887    2021-10-04           NG                Nigeria       AFRO
# 99921     2020-09-09          NaN                Namibia       AFRO
# ...

# %%
turkey_koca=turkey_cases[(turkey_cases["Date_reported"]>"2020-07-28")&(turkey_cases["Date_reported"]<"2020-12-31")]

# %%
plt.figure(figsize=(40,20))
sns.set_theme()
ax = sns.barplot(data=worst_vac,
            x="COUNTRY",
            y="PERSONS_VACCINATED_1PLUS_DOSE_PER100",
            palette="Paired",
            hue="WHO_REGION"
                )
plt.xticks(rotation=90)
ax.set_xlabel("COUNTRIES",fontsize=40)
ax.set_ylabel(" PERCENTAGE OF PEOPLE WHO GOT AT LEAST 1 DOSE OF VACCINE ",fontsize=30)
ax.set_title("100 COUNTRIES WHO GOT LOWEST RATE OF VACCINATION", fontsize=40)
ax.tick_params(labelsize=25)

plt.show()

# %%
plt.figure(figsize=(40,20))
ax = sns.lineplot(data=turkey_koca,
            x="Date_reported",
            y="New_cases"
            )
plt.xticks(rotation=45)
ax.set_xlabel("Date_reported",fontsize=30)
ax.set_ylabel(" DAILY NEW CASE NUMBERS FROM TURKEY",fontsize=30)
ax.set_title("POSSIBLE MANIPILATION OF DATA", fontsize=40)
ax.tick_params(labelsize=25)
plt.show()

# %%
df_general
# Out:
#        Date_reported Country_code      Country WHO_region  New_cases  \
# 0         2020-01-03           AF  Afghanistan       EMRO          0
# 1         2020-01-04           AF  Afghanistan       EMRO          0
# 2         2020-01-05           AF  Afghanistan       EMRO          0
# 3         2020-01-06           AF  Afghanistan       EMRO          0
# 4         2020-01-07           AF  Afghanistan       EMRO          0
# ...              ...          ...          ...        ...        ...
# 165184    2021-11-25           ZW     Zimbabwe       AFRO         40
# 165185    2021-11-26           ZW     Zimbabwe       AFRO         27
# 165186    2021-11-27           ZW     Zimbabwe       AFRO         62
# 165187    2021-11-28           ZW     Zimbabwe       AFRO        115
# 165188    2021-11-29           ZW     Zimbabwe       AFRO         40
#
#         Cumulative_cases  New_deaths  Cumulative_deaths  \
# 0                      0           0                  0
# ...

# %%
turkey_cases[turkey_cases["Date_reported"]=="2020-09-10"]
# Out:
#        Date_reported Country_code Country WHO_region  New_cases  \
# 152197    2020-09-10           TR  Turkey       EURO       8403
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 152197            581063          55               6837

# %%
general_last_20_days = df_general_out_nan[df_general_out_nan["Date_reported"]>"2021-11-09"]

# %%
asd = general_last_20_days.groupby("Country").mean()

# %%
asd.sort_values("New_deaths", ascending=False).head(10)
# Out:
#                              New_cases  Cumulative_cases   New_deaths  \
# Country
# Russian Federation        36528.900000      9.269187e+06  1237.450000
# United States of America  90917.222222      4.708808e+07  1228.333333
# Ukraine                   16016.900000      3.298836e+06   601.200000
# India                     10185.950000      3.449077e+07   370.050000
# Romania                    3290.600000      1.753607e+06   263.950000
# Poland                    19774.650000      3.319374e+06   253.550000
# Brazil                     9821.200000      2.198439e+07   236.950000
# Germany                   49334.100000      5.293091e+06   211.450000
# Turkey                    24327.600000      8.517289e+06   206.600000
# Hungary                   13009.428571      1.000624e+06   200.357143
#
#                           Cumulative_deaths  Health System Power Index
# Country
# Russian Federation            262216.850000                  29.521283
# ...

# %%
asd.sort_values("Health System Power Index")
# Out:
#                 New_cases  Cumulative_cases  New_deaths  Cumulative_deaths  \
# Country
# Grenada          2.000000      5.863000e+03    2.000000         200.000000
# Eswatini         2.000000      4.647767e+04    1.333333        1246.333333
# Senegal          3.000000      7.395700e+04    1.666667        1883.000000
# Gambia           2.000000      9.988000e+03    1.000000         342.000000
# Lesotho          2.333333      2.170300e+04    1.000000         661.000000
# ...                   ...               ...         ...                ...
# Switzerland   5108.058824      9.364856e+05    9.352941       10953.176471
# Netherlands  19350.250000      2.396798e+06   36.700000       18909.500000
# Denmark       3703.600000      4.413817e+05    6.600000        2797.600000
# Réunion       1591.500000      5.811050e+04    2.500000         380.000000
# Norway        1956.666667      2.369973e+05    8.500000        1003.750000
#
#              Health System Power Index
# Country
# ...

# %%
211*697
# Out:
# 147067

# %%
33*211
# Out:
# 6963

# %%
df_general.shape
# Out:
# (165189, 9)

# %%
df_general.groupby(["Country"]).mean()
# Out:
#                                                      New_cases  \
# Country
# Afghanistan                                         225.563845
# Albania                                             286.305595
# Algeria                                             301.509326
# American Samoa                                        0.007174
# Andorra                                              23.977044
# ...                                                        ...
# Wallis and Futuna                                     0.651363
# Yemen                                                14.328551
# Zambia                                              301.496413
# Zimbabwe                                            192.239598
# occupied Palestinian territory, including east ...  660.047346
#
#                                                     Cumulative_cases  \
# Country
# Afghanistan                                             61644.977044
# ...

# %%
df_general.shape
# Out:
# (165189, 9)

# %%
vaccination["difference"] = vaccination["PERSONS_VACCINATED_1PLUS_DOSE_PER100"]-vaccination["PERSONS_FULLY_VACCINATED_PER100"]

# %%
vaccination
# Out:
#                COUNTRY ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  \
# 0          Afghanistan  AFG       EMRO   REPORTING   2021-11-28
# 1              Albania  ALB       EURO   REPORTING   2021-11-21
# 2              Algeria  DZA       AFRO   REPORTING   2021-11-24
# 3       American Samoa  ASM       WPRO   REPORTING   2021-11-24
# 4              Andorra  AND       EURO   REPORTING   2021-10-31
# ..                 ...  ...        ...         ...          ...
# 223           Viet Nam  VNM       WPRO   REPORTING   2021-11-18
# 224  Wallis and Futuna  WLF       WPRO   REPORTING   2021-11-23
# 225              Yemen  YEM       EMRO   REPORTING   2021-11-28
# 226             Zambia  ZMB       AFRO   REPORTING   2021-11-18
# 227           Zimbabwe  ZWE       AFRO   REPORTING   2021-11-23
#
#      TOTAL_VACCINATIONS  PERSONS_VACCINATED_1PLUS_DOSE  \
# 0               4396007                      3896787.0
# 1               2006988                      1064233.0
# ...

# %%
vaccination.groupby(["WHO_REGION"]).mean().sort_values("difference")
# Out:
#             TOTAL_VACCINATIONS  PERSONS_VACCINATED_1PLUS_DOSE  \
# WHO_REGION
# OTHER             5.046900e+04                   2.566100e+04
# AFRO              2.871214e+06                   1.888853e+06
# EURO              1.865588e+07                   9.553512e+06
# EMRO              2.035822e+07                   1.302713e+07
# WPRO              8.681080e+07                   4.239811e+07
# AMRO              2.582943e+07                   1.425795e+07
# SEARO             1.663230e+08                   1.051594e+08
#
#             TOTAL_VACCINATIONS_PER100  PERSONS_VACCINATED_1PLUS_DOSE_PER100  \
# WHO_REGION
# OTHER                      130.253000                             66.227000
# AFRO                        28.446532                             17.593319
# EURO                       119.565350                             60.574949
# EMRO                        73.313182                             33.584789
# ...

# %%
vaccination[(vaccination["COUNTRY"]=="Yemen")|(vaccination["COUNTRY"]=="Syrian Arab Republic")|(vaccination["COUNTRY"]=="Afghanistan")]
# Out:
#                   COUNTRY ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  \
# 0             Afghanistan  AFG       EMRO   REPORTING   2021-11-28
# 200  Syrian Arab Republic  SYR       EMRO   REPORTING   2021-11-28
# 225                 Yemen  YEM       EMRO   REPORTING   2021-11-28
#
#      TOTAL_VACCINATIONS  PERSONS_VACCINATED_1PLUS_DOSE  \
# 0               4396007                      3896787.0
# 200             1422377                       890837.0
# 225              774953                       548933.0
#
#      TOTAL_VACCINATIONS_PER100  PERSONS_VACCINATED_1PLUS_DOSE_PER100  \
# 0                       11.293                                 10.01
# 200                      8.128                                  5.09
# 225                      2.598                                  1.84
#
#      PERSONS_FULLY_VACCINATED  PERSONS_FULLY_VACCINATED_PER100  \
# 0                   3564819.0                            9.157
# ...

# %%
df_general
# Out:
#        Date_reported Country_code      Country WHO_region  New_cases  \
# 0         2020-01-03           AF  Afghanistan       EMRO          0
# 1         2020-01-04           AF  Afghanistan       EMRO          0
# 2         2020-01-05           AF  Afghanistan       EMRO          0
# 3         2020-01-06           AF  Afghanistan       EMRO          0
# 4         2020-01-07           AF  Afghanistan       EMRO          0
# ...              ...          ...          ...        ...        ...
# 165184    2021-11-25           ZW     Zimbabwe       AFRO         40
# 165185    2021-11-26           ZW     Zimbabwe       AFRO         27
# 165186    2021-11-27           ZW     Zimbabwe       AFRO         62
# 165187    2021-11-28           ZW     Zimbabwe       AFRO        115
# 165188    2021-11-29           ZW     Zimbabwe       AFRO         40
#
#         Cumulative_cases  New_deaths  Cumulative_deaths  \
# 0                      0           0                  0
# ...

# %%
df_general.groupby("Country").mean()
# Out:
#                                                      New_cases  \
# Country
# Afghanistan                                         225.563845
# Albania                                             286.305595
# Algeria                                             301.509326
# American Samoa                                        0.007174
# Andorra                                              23.977044
# ...                                                        ...
# Wallis and Futuna                                     0.651363
# Yemen                                                14.328551
# Zambia                                              301.496413
# Zimbabwe                                            192.239598
# occupied Palestinian territory, including east ...  660.047346
#
#                                                     Cumulative_cases  \
# Country
# Afghanistan                                             61644.977044
# ...

# %%
df_general[df_general["Country"]=="Turkey"]
# Out:
#        Date_reported Country_code Country WHO_region  New_cases  \
# 151946    2020-01-03           TR  Turkey       EURO          0
# 151947    2020-01-04           TR  Turkey       EURO          0
# 151948    2020-01-05           TR  Turkey       EURO          0
# 151949    2020-01-06           TR  Turkey       EURO          0
# 151950    2020-01-07           TR  Turkey       EURO          0
# ...              ...          ...     ...        ...        ...
# 152638    2021-11-25           TR  Turkey       EURO      27592
# 152639    2021-11-26           TR  Turkey       EURO      24467
# 152640    2021-11-27           TR  Turkey       EURO      24002
# 152641    2021-11-28           TR  Turkey       EURO      23759
# 152642    2021-11-29           TR  Turkey       EURO      21655
#
#         Cumulative_cases  New_deaths  Cumulative_deaths  \
# 151946                 0           0                  0
# 151947                 0           0                  0
# ...
